# %%
import yfinance as yf

# %%
# 1. Create a Ticker object (e.g., Apple)
ticker = yf.Ticker("AAPL")

# 2. Get the option chain for the nearest expiration date
# Use ticker.options to get a list of all available dates
chain = ticker.option_chain()

# 3. Access Calls and Puts
calls = chain.calls
puts = chain.puts

# %%
chain
# Out:
# Options(calls=         contractSymbol             lastTradeDate  strike  lastPrice    bid  \
# 0   AAPL260701C00225000 2026-07-01 17:04:39+00:00   225.0      68.95  68.20
# 1   AAPL260701C00230000 2026-07-01 17:06:59+00:00   230.0      63.92  63.10
# 2   AAPL260701C00240000 2026-07-01 17:08:03+00:00   240.0      54.12  53.10
# 3   AAPL260701C00245000 2026-07-01 17:06:12+00:00   245.0      49.14  48.10
# 4   AAPL260701C00250000 2026-07-01 18:51:41+00:00   250.0      44.92  43.10
# 5   AAPL260701C00255000 2026-07-01 17:15:38+00:00   255.0      39.15  38.10
# 6   AAPL260701C00260000 2026-07-01 17:35:22+00:00   260.0      34.90  33.25
# 7   AAPL260701C00262500 2026-07-01 17:04:09+00:00   262.5      31.50  30.60
# 8   AAPL260701C00265000 2026-07-01 17:09:46+00:00   265.0      29.21  28.15
# 9   AAPL260701C00267500 2026-07-01 18:46:00+00:00   267.5      27.55  25.60
# 10  AAPL260701C00270000 2026-07-01 19:54:38+00:00   270.0      24.99  23.90
# ...
