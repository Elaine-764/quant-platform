# %% [markdown]
# # Multi Layer Perceptron
# - take these inputs as a tensor
#   - RSI
#   - MACD
#   - VIX
#   - 20-day return
#   - 20-day volatility
#   - TLT return
#   - GLD return
#   - QQQ return
#   - other representative metrics of the market
# - output
#   - expected returns of (almost) every assets (5 day returns)

# %%
import torch
import torch.nn as nn

# %%
# hyperparams
input_num_metrics = 10
input_num_days = 1
input_num_assets = 10
input_size = (input_num_metrics * input_num_days, input_num_assets)
learning_rate = 1e-3
epochs = 5

# %%
class MultiLayerPerceptron(nn.Module):
    def __init__(self, input_dim, hidden_dim, output_dim):
        super(MultiLayerPerceptron, self).__init__()
        # Instantiate layers with trainable parameters
        self.fc1 = nn.Linear(input_dim, hidden_dim)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, output_dim)
        # TODO: probably need to add more layers to this
        
    def forward(self, x):
        # Define the exact execution flow of the data
        out = self.fc1(x)
        out = self.relu(out)
        out = self.fc2(out)
        return out

# Instantiate the custom model
model = MultiLayerPerceptron(input_dim=784, hidden_dim=128, output_dim=10) # TODO: customize dimensions

# %%
class TradingMLP(nn.Module):
    def __init__(self, input_dim):
        super().__init__()

        self.net = nn.Sequential(
            nn.Linear(input_dim, 256),
            nn.ReLU(),

            nn.Linear(256, 128),
            nn.ReLU(),

            nn.Linear(128, 64),
            nn.ReLU(),

            nn.Linear(64, 1)
        )

    def forward(self, x):
        return self.net(x)
