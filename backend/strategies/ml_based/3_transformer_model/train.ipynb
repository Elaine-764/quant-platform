# %% [markdown]
# ## Notes
# - train a transformer model for each of the assets?
# - different models
#   - classification
#     - directional

# %%
import torch
import torch.nn as nn

# %%
# hyperparameters

# %%
# define source and target
